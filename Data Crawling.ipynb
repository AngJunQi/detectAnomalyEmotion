# %%
import tweepy
import csv
import pandas as pd

access_token = "(Go get your own access token from Twitter Developer Account)"
access_token_secret = "(Go get your own access token from Twitter Developer Account)"
api_key = "(Go get your own access token from Twitter Developer Account)"
api_key_secret = "(Go get your own access token from Twitter Developer Account)"

auth = tweepy.OAuthHandler(api_key,api_key_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit = True)
search_key = "Spritzer"

csvFile = open(search_key+"1.csv", "a+", newline="", encoding="utf-8")
csvWriter = csv.writer(csvFile)
c = []
i = []
u = []
t = []

for tweet in tweepy.Cursor(api.search, q = search_key, count = 1000, lang ="en", since = "2021-06-19", until = "2021-07-21").items():
    print(tweet.created_at, tweet.id, tweet.user.name, tweet.text)
    c.append(tweet.created_at)
    i.append(tweet.id)
    u.append(tweet.user.name)
    t.append(tweet.text.encode("utf-8"))
    tweets = [tweet.created_at, tweet.id, tweet.user.name, tweet.text.encode("utf-8")]
    csvWriter.writerow(tweets)
    
dictTweets = {"time":c, "id":i, "username":u, "text":t}
df = pd.DataFrame(dictTweets,columns = ["time", "id", "username", "text"])
df
# Out:
# 2021-06-17 12:18:07 1405499998817513476 SR RT @avetilearning: Join us this Sunday, let's meet Sanjita Mohapatra, who aced UPSC CSE 2019 by securing an All India Rank of 10. Let's hea…
# 2021-06-17 12:12:16 1405498528781193216 Raerae Also, progress is not always linear. There are ancient recipes we have not been able to replicate for years or even… https://t.co/lltiLgWxzl
# 2021-06-17 11:51:07 1405493205714542593 Annon Me: when I discovered the 'secret recipe' of #cococola https://t.co/rJLBNCFDDI
# 2021-06-17 11:27:17 1405487206324654083 The Happy Veg ✌🥑🌈 https://t.co/tuMvE2e48D
#
# Did someone say #esquites ? get the #recipe now!
# Plus, you can #shop the secret ingredient… https://t.co/yJU49q0RVE
# 2021-06-17 11:18:20 1405484952829976581 Keithrinekelvin RT @ToddWilbur: Now you can make 1 cup of the secret creamy Baja sauce that comes on a Gordita or Chalupa at Taco Bell to use at home on yo…
# ...

# %%
import pandas as pd

df = pd.read_csv("Secret Recipe.csv")
df[~df.duplicated()].to_csv('Secret Recipe(NoDup).csv')
df
# Out:
# 0       b'RT @mhazimhamdan: Ni air starbuck rahsia dar...
# 1       b'RT @peteprodge: Brewdog is trending because ...
# 2       b'The secret recipe to progress - The Up Devot...
# 3       b'RT @peteprodge: Brewdog is trending because ...
# 4       b'RT @Davidoooey: New Secret 1.6 Food Recipes\...
#                               ...
# 4584    b"RT @Gatonetillo: @kfc Is animal cruelty part...
# 4585    b"@kfc Is animal cruelty part of @KFC's secret...
# 4586    b'RT @princess_antifa: i released my secret re...
# 4587    b'Another Great #RECIPE Post from #FTHM\n\nPle...
# 4588    b"Me: when I discovered the 'secret recipe' of...
# Name: Text, Length: 4589, dtype: object

# %%
import nltk
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')
stopwords[0:10]

# %%
def remove_stopwords(txt_tokenized):
    txt_clean = [word for word in txt_tokenized if word not in stopwords]
    return txt_clean

df['Text'] = df['Text'].apply(lambda x: remove_stopwords(x))
df['Text']

# %%
import string
df['Text'] = [word.lower() for word in df['Text']]
df['Text']
